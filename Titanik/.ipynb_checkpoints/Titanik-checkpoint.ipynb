# %%
# Importing libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as mpl
from matplotlib import pyplot as plt
from wordcloud import WordCloud
from sklearn.metrics import accuracy_score, log_loss
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_validate
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import cross_val_predict
from sklearn.metrics import confusion_matrix
from sklearn.svm import SVC, LinearSVC
from xgboost import XGBClassifier
from sklearn.preprocessing import LabelEncoder
# %matplotlib inline

# %%
trd = pd.read_csv('train.csv', keep_default_na=False)
tsd = pd.read_csv('test.csv')
td = pd.concat([trd, tsd], ignore_index=True, sort = False)

# %%
td.isnull().sum()
sns.heatmap(td.isnull(), cbar = False).set_title("Missing values heatmap")
# Out:
# Text(0.5, 1.0, 'Missing values heatmap')

# %%
td['Fare_Category'] = pd.cut(td['Fare'], bins=[0,7.90,14.45,31.28,120], labels=['Low','Mid', 'High_Mid','High'])

# %%
fig_pclass = trd.Pclass.value_counts().plot.pie().legend(labels=["Class 3","Class 1","Class 2"], loc='center right', bbox_to_anchor=(2.25, 0.5)).set_title("Training Data - People travelling in different classes")

# %%
print(trd.Pclass.value_counts())
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
fig_pclass = trd.Pclass.value_counts().plot.pie()

# %%
pclass_1_survivor_distribution = round((trd[trd.Pclass == 1].Survived == 1).value_counts()[1]/len(trd[trd.Pclass == 1]) * 100, 2)
pclass_2_survivor_distribution = round((trd[trd.Pclass == 2].Survived == 1).value_counts()[1]/len(trd[trd.Pclass == 2]) * 100, 2)
pclass_3_survivor_distribution = round((trd[trd.Pclass == 3].Survived == 1).value_counts()[1]/len(trd[trd.Pclass == 3]) * 100, 2)
pclass_perc_df = pd.DataFrame(
    { "Percentage Survived":{"Class 1": pclass_1_survivor_distribution,"Class 2": pclass_2_survivor_distribution, "Class 3": pclass_3_survivor_distribution},  
     "Percentage Not Survived":{"Class 1": 100-pclass_1_survivor_distribution,"Class 2": 100-pclass_2_survivor_distribution, "Class 3": 100-pclass_3_survivor_distribution}})
pclass_perc_df.plot.bar().set_title("Training Data - Percentage of people survived on the basis of class")
# Out:
# Text(0.5, 1.0, 'Training Data - Percentage of people survived on the basis of class')

# %%
print (trd.notnull().any(axis = 0))
# Out:
# PassengerId    True
# Survived       True
# Pclass         True
# Name           True
# Sex            True
# Age            True
# SibSp          True
# Parch          True
# Ticket         True
# Fare           True
# Cabin          True
# Embarked       True
# dtype: bool

# %%
df = trd.loc[:, trd.notnull().any(axis = 0)]
print (df)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38      1
# 2                               Heikkinen, Miss. Laina  female  26      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35      1
# 4                             Allen, Mr. William Henry    male  35      0
# ..                                                 ...     ...  ..    ...
# 886                              Montvila, Rev. Juozas    male  27      0
# 887                       Graham, Miss. Margaret Edith  female  19      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female          1
# 889                              Behr, Mr. Karl Howell    male  26      0
# 890                                Dooley, Mr. Patrick    male  32      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500              S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250              S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500              S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000              S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500              S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500              Q
#
# [891 rows x 12 columns]

# %%
trd.loc[
    (trd['Pclass'] == 1) &
    (trd['Sex'] == 'female') & 
    (trd['Survived'] == 1)
]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 11            12         1       1
# 31            32         1       1
# 52            53         1       1
# ..           ...       ...     ...
# 856          857         1       1
# 862          863         1       1
# 871          872         1       1
# 879          880         1       1
# 887          888         1       1
#
#                                                   Name     Sex Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35      1
# 11                            Bonnell, Miss. Elizabeth  female  58      0
# 31      Spencer, Mrs. William Augustus (Marie Eugenie)  female          1
# 52            Harper, Mrs. Henry Sleeper (Myna Haxtun)  female  49      1
# ..                                                 ...     ...  ..    ...
# 856         Wick, Mrs. George Dennick (Mary Hitchcock)  female  45      1
# 862  Swift, Mrs. Frederick Joel (Margaret Welles Ba...  female  48      0
# 871   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  female  47      1
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56      0
# 887                       Graham, Miss. Margaret Edith  female  19      0
#
#      Parch    Ticket      Fare Cabin Embarked
# 1        0  PC 17599   71.2833   C85        C
# 3        0    113803   53.1000  C123        S
# 11       0    113783   26.5500  C103        S
# 31       0  PC 17569  146.5208   B78        C
# 52       0  PC 17572   76.7292   D33        C
# ..     ...       ...       ...   ...      ...
# 856      1     36928  164.8667              S
# 862      0     17466   25.9292   D17        S
# 871      1     11751   52.5542   D35        S
# 879      1     11767   83.1583   C50        C
# 887      0    112053   30.0000   B42        S
#
# [91 rows x 12 columns]

# %%
trd[
    (trd['Pclass'] == 2) &
    (trd['Sex'] == 'female') & 
    (trd['Survived'] == 1)
].value_counts()
# Out:
# PassengerId  Survived  Pclass  Name                                                 Sex     Age  SibSp  Parch  Ticket           Fare     Cabin  Embarked
# 881          1         2       Shelley, Mrs. William (Imanita Parrish Hall)         female  25   0      1      230433           26.0000         S           1
# 388          1         2       Buss, Miss. Kate                                     female  36   0      0      27849            13.0000         S           1
# 317          1         2       Kantor, Mrs. Sinai (Miriam Sternin)                  female  24   1      0      244367           26.0000         S           1
# 323          1         2       Slayter, Miss. Hilda Mary                            female  30   0      0      234818           12.3500         Q           1
# 324          1         2       Caldwell, Mrs. Albert Francis (Sylvia Mae Harbaugh)  female  22   1      1      248738           29.0000         S           1
#                                                                                                                                                            ..
# 507          1         2       Quick, Mrs. Frederick Charles (Jane Richards)        female  33   0      2      26360            26.0000         S           1
# 474          1         2       Jerwan, Mrs. Amin S (Marie Marthe Thuillard)         female  23   0      0      SC/AH Basle 541  13.7917  D      C           1
# 473          1         2       West, Mrs. Edwy Arthur (Ada Mary Worth)              female  33   1      2      C.A. 34651       27.7500         S           1
# 459          1         2       Toomey, Miss. Ellen                                  female  50   0      0      F.C.C. 13531     10.5000         S           1
# 10           1         2       Nasser, Mrs. Nicholas (Adele Achem)                  female  14   1      0      237736           30.0708         C           1
# Length: 70, dtype: int64

# %%
trd.loc[
    (trd['Pclass'] == 3) &
    (trd['Sex'] == 'female') & 
    (trd['Survived'] == 1)
]
# Out:
#      PassengerId  Survived  Pclass  \
# 2              3         1       3
# 8              9         1       3
# 10            11         1       3
# 19            20         1       3
# 22            23         1       3
# ..           ...       ...     ...
# 823          824         1       3
# 830          831         1       3
# 855          856         1       3
# 858          859         1       3
# 875          876         1       3
#
#                                                   Name     Sex Age  SibSp  \
# 2                               Heikkinen, Miss. Laina  female  26      0
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4      1
# 19                             Masselmani, Mrs. Fatima  female          0
# 22                         McGowan, Miss. Anna "Annie"  female  15      0
# ..                                                 ...     ...  ..    ...
# 823                                 Moor, Mrs. (Beila)  female  27      0
# 830            Yasbeck, Mrs. Antoni (Selini Alexander)  female  15      1
# 855                         Aks, Mrs. Sam (Leah Rosen)  female  18      0
# 858              Baclini, Mrs. Solomon (Latifa Qurban)  female  24      0
# 875                   Najib, Miss. Adele Kiamie "Jane"  female  15      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 2        0  STON/O2. 3101282   7.9250              S
# 8        2            347742  11.1333              S
# 10       1           PP 9549  16.7000    G6        S
# 19       0              2649   7.2250              C
# 22       0            330923   8.0292              Q
# ..     ...               ...      ...   ...      ...
# 823      1            392096  12.4750  E121        S
# 830      0              2659  14.4542              C
# 855      1            392091   9.3500              S
# 858      3              2666  19.2583              C
# 875      0              2667   7.2250              C
#
# [72 rows x 12 columns]

# %%
print(trd['Sex'])
# Out:
# 0        male
# 1      female
# 2      female
# 3      female
# 4        male
#         ...
# 886      male
# 887    female
# 888    female
# 889      male
# 890      male
# Name: Sex, Length: 891, dtype: object

# %%
# https://keras.io/api/models/sequential/
# https://keras.io/api/models/model/
# 
import tensorflow as tf

# %%
model = tf.keras.Sequential()
#  Input - Layer
model.add(tf.keras.layers.Dense(8, input_shape=(16,)))

# %%
model.add(tf.keras.layers.Dropout(0.3, noise_shape=None, seed=None))
model.add(tf.keras.layers.Dense(50, activation = "relu"))
model.add(tf.keras.layers.Dropout(0.1, noise_shape=None, seed=None))
model.add(tf.keras.layers.Dense(50, activation = "relu"))
model.add(tf.keras.layers.Dropout(0.1, noise_shape=None, seed=None))
model.add(tf.keras.layers.Dense(6, activation = "relu"))

# %%
# Output- Layer
model.add(tf.keras.layers.Dense(2, activation = "sigmoid"))
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_10 (Dense)            (None, 8)                 136
#
#  dropout_6 (Dropout)         (None, 8)                 0
#
#  dense_11 (Dense)            (None, 50)                450
#
#  dropout_7 (Dropout)         (None, 50)                0
#
#  dense_12 (Dense)            (None, 50)                2550
#
#  dropout_8 (Dropout)         (None, 50)                0
#
#  dense_13 (Dense)            (None, 6)                 306
#
#  dense_14 (Dense)            (None, 2)                 14
#
# =================================================================
# Total params: 3,456
# Trainable params: 3,456
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(
 optimizer = "adam",
 loss = "binary_crossentropy",
 metrics = ["accuracy"]
)

# %%
#results = model.fit( trd, epochs = 3,  batch_size = 500, validation_data = tsd)

# %%
pd.get_dummies(trd.Sex, prefix="Sex", drop_first = False)
# Out:
#      Sex_female  Sex_male
# 0             0         1
# 1             1         0
# 2             1         0
# 3             1         0
# 4             0         1
# ..          ...       ...
# 886           0         1
# 887           1         0
# 888           1         0
# 889           0         1
# 890           0         1
#
# [891 rows x 2 columns]

# %%
pd.get_dummies(trd.Embarked, prefix="Emb", drop_first = False)
# Out:
#      Emb_  Emb_C  Emb_Q  Emb_S
# 0       0      0      0      1
# 1       0      1      0      0
# 2       0      0      0      1
# 3       0      0      0      1
# 4       0      0      0      1
# ..    ...    ...    ...    ...
# 886     0      0      0      1
# 887     0      0      0      1
# 888     0      0      0      1
# 889     0      1      0      0
# 890     0      0      1      0
#
# [891 rows x 4 columns]

# %%
trd['Salutation'] = trd.Name.apply(lambda name: name.split(',')[1].split('.')[0].strip()) 
trd.Salutation.nunique()
wc = WordCloud(width = 1000,height = 450,background_color = 'white').generate(str(trd.Salutation.values))
plt.imshow(wc, interpolation = 'bilinear')
plt.axis('off')
plt.tight_layout(pad=0)
plt.show()


trd_no_age = trd.loc[trd.Age == ""]
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    display (trd_no_age.Name.apply(lambda name: name.split(',')[1].split('.')[0].strip()))

trd['Salutation_no_age'] = trd_no_age.Name.apply(lambda name: name.split(',')[1].split('.')[0].strip()) 
trd.Salutation_no_age.nunique()
wc = WordCloud(width = 1000,height = 450,background_color = 'white').generate(str(trd.Salutation_no_age.values))
plt.imshow(wc, interpolation = 'bilinear')
plt.axis('off')
plt.tight_layout(pad=0)
plt.show()

trd['Salutation_no_age'].value_counts()
# Out:
# 5        Mr
# 17       Mr
# 19      Mrs
# 26       Mr
# 28     Miss
#        ...
# 859      Mr
# 863    Miss
# 868      Mr
# 878      Mr
# 888    Miss
# Name: Name, Length: 177, dtype: object
# Mr        119
# Miss       36
# Mrs        17
# Master      4
# Dr          1
# Name: Salutation_no_age, dtype: int64

# %%
grp = trd.groupby(['Sex', 'Pclass'])  
for key, item in grp:
    print(key, "->", item)

trd.Age = grp.Age.apply(lambda x: x.fillna(x.median()))
print(td.Age)
#If still any row remains
trd.Age.fillna(trd.Age.median, inplace = True)
# Out:
# ('female', 1) ->      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 11            12         1       1
# 31            32         1       1
# 52            53         1       1
# ..           ...       ...     ...
# 856          857         1       1
# 862          863         1       1
# 871          872         1       1
# 879          880         1       1
# 887          888         1       1
#
#                                                   Name     Sex Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35      1
# 11                            Bonnell, Miss. Elizabeth  female  58      0
# 31      Spencer, Mrs. William Augustus (Marie Eugenie)  female          1
# 52            Harper, Mrs. Henry Sleeper (Myna Haxtun)  female  49      1
# ..                                                 ...     ...  ..    ...
# 856         Wick, Mrs. George Dennick (Mary Hitchcock)  female  45      1
# 862  Swift, Mrs. Frederick Joel (Margaret Welles Ba...  female  48      0
# 871   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  female  47      1
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56      0
# 887                       Graham, Miss. Margaret Edith  female  19      0
#
#      Parch    Ticket      Fare Cabin Embarked Salutation Salutation_no_age
# 1        0  PC 17599   71.2833   C85        C        Mrs               NaN
# 3        0    113803   53.1000  C123        S        Mrs               NaN
# 11       0    113783   26.5500  C103        S       Miss               NaN
# 31       0  PC 17569  146.5208   B78        C        Mrs               Mrs
# 52       0  PC 17572   76.7292   D33        C        Mrs               NaN
# ..     ...       ...       ...   ...      ...        ...               ...
# 856      1     36928  164.8667              S        Mrs               NaN
# 862      0     17466   25.9292   D17        S        Mrs               NaN
# 871      1     11751   52.5542   D35        S        Mrs               NaN
# 879      1     11767   83.1583   C50        C        Mrs               NaN
# 887      0    112053   30.0000   B42        S       Miss               NaN
#
# [94 rows x 14 columns]
# ('female', 2) ->      PassengerId  Survived  Pclass  \
# 9             10         1       2
# 15            16         1       2
# 41            42         0       2
# 43            44         1       2
# 53            54         1       2
# ..           ...       ...     ...
# 854          855         0       2
# 865          866         1       2
# 866          867         1       2
# 874          875         1       2
# 880          881         1       2
#
#                                                   Name     Sex Age  SibSp  \
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14      1
# 15                    Hewlett, Mrs. (Mary D Kingcome)   female  55      0
# 41   Turpin, Mrs. William John Robert (Dorothy Ann ...  female  27      1
# 43            Laroche, Miss. Simonne Marie Anne Andree  female   3      1
# 53   Faunthorpe, Mrs. Lizzie (Elizabeth Anne Wilkin...  female  29      1
# ..                                                 ...     ...  ..    ...
# 854      Carter, Mrs. Ernest Courtenay (Lilian Hughes)  female  44      1
# 865                           Bystrom, Mrs. (Karolina)  female  42      0
# 866                       Duran y More, Miss. Asuncion  female  27      1
# 874              Abelson, Mrs. Samuel (Hannah Wizosky)  female  28      1
# 880       Shelley, Mrs. William (Imanita Parrish Hall)  female  25      0
#
#      Parch         Ticket     Fare Cabin Embarked Salutation Salutation_no_age
# 9        0         237736  30.0708              C        Mrs               NaN
# 15       0         248706  16.0000              S        Mrs               NaN
# 41       0          11668  21.0000              S        Mrs               NaN
# 43       2  SC/Paris 2123  41.5792              C       Miss               NaN
# 53       0           2926  26.0000              S        Mrs               NaN
# ..     ...            ...      ...   ...      ...        ...               ...
# 854      0         244252  26.0000              S        Mrs               NaN
# 865      0         236852  13.0000              S        Mrs               NaN
# 866      0  SC/PARIS 2149  13.8583              C       Miss               NaN
# 874      0      P/PP 3381  24.0000              C        Mrs               NaN
# 880      1         230433  26.0000              S        Mrs               NaN
#
# [76 rows x 14 columns]
# ('female', 3) ->      PassengerId  Survived  Pclass  \
# 2              3         1       3
# 8              9         1       3
# 10            11         1       3
# 14            15         0       3
# 18            19         0       3
# ..           ...       ...     ...
# 863          864         0       3
# 875          876         1       3
# 882          883         0       3
# 885          886         0       3
# 888          889         0       3
#
#                                                   Name     Sex Age  SibSp  \
# 2                               Heikkinen, Miss. Laina  female  26      0
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4      1
# 14                Vestrom, Miss. Hulda Amanda Adolfina  female  14      0
# 18   Vander Planke, Mrs. Julius (Emelia Maria Vande...  female  31      1
# ..                                                 ...     ...  ..    ...
# 863                  Sage, Miss. Dorothy Edith "Dolly"  female          8
# 875                   Najib, Miss. Adele Kiamie "Jane"  female  15      0
# 882                       Dahlberg, Miss. Gerda Ulrika  female  22      0
# 885               Rice, Mrs. William (Margaret Norton)  female  39      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female          1
#
#      Parch            Ticket     Fare Cabin Embarked Salutation  \
# 2        0  STON/O2. 3101282   7.9250              S       Miss
# 8        2            347742  11.1333              S        Mrs
# 10       1           PP 9549  16.7000    G6        S       Miss
# 14       0            350406   7.8542              S       Miss
# 18       0            345763  18.0000              S        Mrs
# ..     ...               ...      ...   ...      ...        ...
# 863      2          CA. 2343  69.5500              S       Miss
# 875      0              2667   7.2250              C       Miss
# 882      0              7552  10.5167              S       Miss
# 885      5            382652  29.1250              Q        Mrs
# 888      2        W./C. 6607  23.4500              S       Miss
#
#     Salutation_no_age
# 2                 NaN
# 8                 NaN
# 10                NaN
# 14                NaN
# 18                NaN
# ..                ...
# 863              Miss
# 875               NaN
# 882               NaN
# 885               NaN
# 888              Miss
#
# [144 rows x 14 columns]
# ('male', 1) ->      PassengerId  Survived  Pclass                                  Name  \
# 6              7         0       1               McCarthy, Mr. Timothy J
# 23            24         1       1          Sloper, Mr. William Thompson
# 27            28         0       1        Fortune, Mr. Charles Alexander
# 30            31         0       1              Uruchurtu, Don. Manuel E
# 34            35         0       1               Meyer, Mr. Edgar Joseph
# ..           ...       ...     ...                                   ...
# 839          840         1       1                  Marechal, Mr. Pierre
# 857          858         1       1                Daly, Mr. Peter Denis
# 867          868         0       1  Roebling, Mr. Washington Augustus II
# 872          873         0       1              Carlsson, Mr. Frans Olof
# 889          890         1       1                 Behr, Mr. Karl Howell
#
#       Sex Age  SibSp  Parch    Ticket      Fare        Cabin Embarked  \
# 6    male  54      0      0     17463   51.8625          E46        S
# 23   male  28      0      0    113788   35.5000           A6        S
# 27   male  19      3      2     19950  263.0000  C23 C25 C27        S
# 30   male  40      0      0  PC 17601   27.7208                     C
# 34   male  28      1      0  PC 17604   82.1708                     C
# ..    ...  ..    ...    ...       ...       ...          ...      ...
# 839  male          0      0     11774   29.7000          C47        C
# 857  male  51      0      0    113055   26.5500          E17        S
# 867  male  31      0      0  PC 17590   50.4958          A24        S
# 872  male  33      0      0       695    5.0000  B51 B53 B55        S
# 889  male  26      0      0    111369   30.0000         C148        C
#
#     Salutation Salutation_no_age
# 6           Mr               NaN
# 23          Mr               NaN
# 27          Mr               NaN
# 30         Don               NaN
# 34          Mr               NaN
# ..         ...               ...
# 839         Mr                Mr
# 857         Mr               NaN
# 867         Mr               NaN
# 872         Mr               NaN
# 889         Mr               NaN
#
# [122 rows x 14 columns]
# ('male', 2) ->      PassengerId  Survived  Pclass                           Name   Sex Age  \
# 17            18         1       2   Williams, Mr. Charles Eugene  male
# 20            21         0       2           Fynney, Mr. Joseph J  male  35
# 21            22         1       2          Beesley, Mr. Lawrence  male  34
# 33            34         0       2          Wheadon, Mr. Edward H  male  66
# 70            71         0       2     Jenkin, Mr. Stephen Curnow  male  32
# ..           ...       ...     ...                            ...   ...  ..
# 848          849         0       2              Harper, Rev. John  male  28
# 861          862         0       2    Giles, Mr. Frederick Edward  male  21
# 864          865         0       2         Gill, Mr. John William  male  24
# 883          884         0       2  Banfield, Mr. Frederick James  male  28
# 886          887         0       2          Montvila, Rev. Juozas  male  27
#
#      SibSp  Parch            Ticket  Fare Cabin Embarked Salutation  \
# 17       0      0            244373  13.0              S         Mr
# 20       0      0            239865  26.0              S         Mr
# 21       0      0            248698  13.0   D56        S         Mr
# 33       0      0        C.A. 24579  10.5              S         Mr
# 70       0      0        C.A. 33111  10.5              S         Mr
# ..     ...    ...               ...   ...   ...      ...        ...
# 848      0      1            248727  33.0              S        Rev
# 861      1      0             28134  11.5              S         Mr
# 864      0      0            233866  13.0              S         Mr
# 883      0      0  C.A./SOTON 34068  10.5              S         Mr
# 886      0      0            211536  13.0              S        Rev
#
#     Salutation_no_age
# 17                 Mr
# 20                NaN
# 21                NaN
# 33                NaN
# 70                NaN
# ..                ...
# 848               NaN
# 861               NaN
# 864               NaN
# 883               NaN
# 886               NaN
#
# [108 rows x 14 columns]
# ('male', 3) ->      PassengerId  Survived  Pclass                            Name   Sex Age  \
# 0              1         0       3         Braund, Mr. Owen Harris  male  22
# 4              5         0       3        Allen, Mr. William Henry  male  35
# 5              6         0       3                Moran, Mr. James  male
# 7              8         0       3  Palsson, Master. Gosta Leonard  male   2
# 12            13         0       3  Saundercock, Mr. William Henry  male  20
# ..           ...       ...     ...                             ...   ...  ..
# 877          878         0       3            Petroff, Mr. Nedelio  male  19
# 878          879         0       3              Laleff, Mr. Kristo  male
# 881          882         0       3              Markun, Mr. Johann  male  33
# 884          885         0       3          Sutehall, Mr. Henry Jr  male  25
# 890          891         0       3             Dooley, Mr. Patrick  male  32
#
#      SibSp  Parch           Ticket     Fare Cabin Embarked Salutation  \
# 0        1      0        A/5 21171   7.2500              S         Mr
# 4        0      0           373450   8.0500              S         Mr
# 5        0      0           330877   8.4583              Q         Mr
# 7        3      1           349909  21.0750              S     Master
# 12       0      0        A/5. 2151   8.0500              S         Mr
# ..     ...    ...              ...      ...   ...      ...        ...
# 877      0      0           349212   7.8958              S         Mr
# 878      0      0           349217   7.8958              S         Mr
# 881      0      0           349257   7.8958              S         Mr
# 884      0      0  SOTON/OQ 392076   7.0500              S         Mr
# 890      0      0           370376   7.7500              Q         Mr
#
#     Salutation_no_age
# 0                 NaN
# 4                 NaN
# 5                  Mr
# 7                 NaN
# 12                NaN
# ..                ...
# 877               NaN
# 878                Mr
# 881               NaN
# 884               NaN
# 890               NaN
#
# [347 rows x 14 columns]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/.local/lib/python3.8/site-packages/pandas/core/nanops.py in nanmedian(values, axis, skipna, mask)
#     612         try:
# --> 613             values = values.astype("f8")
#     614         except ValueError as err:
#
# ValueError: could not convert string to float: ''
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# ~/.local/lib/python3.8/site-packages/pandas/core/groupby/groupby.py in apply(self, func, *args, **kwargs)
#     858             try:
# --> 859                 result = self._python_apply_general(f, self._selected_obj)
#     860             except TypeError:
#
# ~/.local/lib/python3.8/site-packages/pandas/core/groupby/groupby.py in _python_apply_general(self, f, data)
#     891         """
# --> 892         keys, values, mutated = self.grouper.apply(f, data, self.axis)
#     893
#
# ~/.local/lib/python3.8/site-packages/pandas/core/groupby/ops.py in apply(self, f, data, axis)
#     212             group_axes = group.axes
# --> 213             res = f(group)
#     214             if not _is_indexed_like(res, group_axes):
#
# <ipython-input-86-d78f8258b56d> in <lambda>(x)
#       4
# ----> 5 trd.Age = grp.Age.apply(lambda x: x.fillna(x.median()))
#       6 print(td.Age)
#
# ~/.local/lib/python3.8/site-packages/pandas/core/generic.py in stat_func(self, axis, skipna, level, numeric_only, **kwargs)
#   11467             return self._agg_by_level(name, axis=axis, level=level, skipna=skipna)
# > 11468         return self._reduce(
#   11469             func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#
# ~/.local/lib/python3.8/site-packages/pandas/core/series.py in _reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    4247             with np.errstate(all="ignore"):
# -> 4248                 return op(delegate, skipna=skipna, **kwds)
#    4249
#
# ~/.local/lib/python3.8/site-packages/pandas/core/nanops.py in f(values, axis, skipna, **kwds)
#     128             else:
# --> 129                 result = alt(values, axis=axis, skipna=skipna, **kwds)
#     130
#
# ~/.local/lib/python3.8/site-packages/pandas/core/nanops.py in nanmedian(values, axis, skipna, mask)
#     615             # e.g. "could not convert string to float: 'a'"
# --> 616             raise TypeError from err
#     617         if mask is not None:
#
# TypeError:
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~/.local/lib/python3.8/site-packages/pandas/core/nanops.py in nanmedian(values, axis, skipna, mask)
#     612         try:
# --> 613             values = values.astype("f8")
#     614         except ValueError as err:
#
# ValueError: could not convert string to float: ''
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-86-d78f8258b56d> in <module>
#       3     print(key, "->", item)
#       4
# ----> 5 trd.Age = grp.Age.apply(lambda x: x.fillna(x.median()))
#       6 print(td.Age)
#       7 #If still any row remains
#
# ~/.local/lib/python3.8/site-packages/pandas/core/groupby/generic.py in apply(self, func, *args, **kwargs)
#     224     )
#     225     def apply(self, func, *args, **kwargs):
# --> 226         return super().apply(func, *args, **kwargs)
#     227
#     228     @doc(
#
# ~/.local/lib/python3.8/site-packages/pandas/core/groupby/groupby.py in apply(self, func, *args, **kwargs)
#     868
#     869                 with _group_selection_context(self):
# --> 870                     return self._python_apply_general(f, self._selected_obj)
#     871
#     872         return result
#
# ~/.local/lib/python3.8/site-packages/pandas/core/groupby/groupby.py in _python_apply_general(self, f, data)
#     890             data after applying f
#     891         """
# --> 892         keys, values, mutated = self.grouper.apply(f, data, self.axis)
#     893
#     894         return self._wrap_applied_output(
#
# ~/.local/lib/python3.8/site-packages/pandas/core/groupby/ops.py in apply(self, f, data, axis)
#     211             # group might be modified
#     212             group_axes = group.axes
# --> 213             res = f(group)
#     214             if not _is_indexed_like(res, group_axes):
#     215                 mutated = True
#
# <ipython-input-86-d78f8258b56d> in <lambda>(x)
#       3     print(key, "->", item)
#       4
# ----> 5 trd.Age = grp.Age.apply(lambda x: x.fillna(x.median()))
#       6 print(td.Age)
#       7 #If still any row remains
#
# ~/.local/lib/python3.8/site-packages/pandas/core/generic.py in stat_func(self, axis, skipna, level, numeric_only, **kwargs)
#   11466         if level is not None:
#   11467             return self._agg_by_level(name, axis=axis, level=level, skipna=skipna)
# > 11468         return self._reduce(
#   11469             func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   11470         )
#
# ~/.local/lib/python3.8/site-packages/pandas/core/series.py in _reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    4246                 )
#    4247             with np.errstate(all="ignore"):
# -> 4248                 return op(delegate, skipna=skipna, **kwds)
#    4249
#    4250     def _reindex_indexer(self, new_index, indexer, copy):
#
# ~/.local/lib/python3.8/site-packages/pandas/core/nanops.py in f(values, axis, skipna, **kwds)
#     127                     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     128             else:
# --> 129                 result = alt(values, axis=axis, skipna=skipna, **kwds)
#     130
#     131             return result
#
# ~/.local/lib/python3.8/site-packages/pandas/core/nanops.py in nanmedian(values, axis, skipna, mask)
#     614         except ValueError as err:
#     615             # e.g. "could not convert string to float: 'a'"
# --> 616             raise TypeError from err
#     617         if mask is not None:
#     618             values[mask] = np.nan
#
# TypeError:
